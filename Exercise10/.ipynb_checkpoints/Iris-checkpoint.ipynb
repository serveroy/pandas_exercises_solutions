# %% [markdown]
# # Iris (part a)

# %% [markdown]
# ### Introduction:
#
# This exercise may seem a little bit strange, but keep doing it.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data).

# %% [markdown]
# ### Step 3. Assign it to a variable called iris

# %%
iris = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data", sep = ",", header=None)
iris

# header=None ensures that the first row won't be read as the columns
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Step 4. Create columns for the dataset

# %%
# 1. sepal_length (in cm)
# 2. sepal_width (in cm)
# 3. petal_length (in cm)
# 4. petal_width (in cm)
# 5. class

iris.columns = ["sepal_length", "sapal_length", "petal_length", "patal_length", "class"]
iris
# Out:
#      sepal_length  sapal_length  petal_length  patal_length           class
# 0             5.1           3.5           1.4           0.2     Iris-setosa
# 1             4.9           3.0           1.4           0.2     Iris-setosa
# 2             4.7           3.2           1.3           0.2     Iris-setosa
# 3             4.6           3.1           1.5           0.2     Iris-setosa
# 4             5.0           3.6           1.4           0.2     Iris-setosa
# ..            ...           ...           ...           ...             ...
# 145           6.7           3.0           5.2           2.3  Iris-virginica
# 146           6.3           2.5           5.0           1.9  Iris-virginica
# 147           6.5           3.0           5.2           2.0  Iris-virginica
# 148           6.2           3.4           5.4           2.3  Iris-virginica
# 149           5.9           3.0           5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Step 5.  Is there any missing value in the dataframe?

# %%
bool(iris.isna().sum().sum() > 0)
# Out:
# False

# %% [markdown]
# ### Step 6.  Lets set the values of the rows 10 to 29 of the column 'petal_length' to NaN

# %%
iris.loc[10:29, "petal_length"] = np.nan
iris.head(32)
# Out:
#     sepal_length  sapal_length  petal_length  patal_length        class
# 0            5.1           3.5           1.4           0.2  Iris-setosa
# 1            4.9           3.0           1.4           0.2  Iris-setosa
# 2            4.7           3.2           1.3           0.2  Iris-setosa
# 3            4.6           3.1           1.5           0.2  Iris-setosa
# 4            5.0           3.6           1.4           0.2  Iris-setosa
# 5            5.4           3.9           1.7           0.4  Iris-setosa
# 6            4.6           3.4           1.4           0.3  Iris-setosa
# 7            5.0           3.4           1.5           0.2  Iris-setosa
# 8            4.4           2.9           1.4           0.2  Iris-setosa
# 9            4.9           3.1           1.5           0.1  Iris-setosa
# 10           5.4           3.7           NaN           0.2  Iris-setosa
# 11           4.8           3.4           NaN           0.2  Iris-setosa
# ...

# %% [markdown]
# ### Step 7. Good, now lets substitute the NaN values to 1.0

# %%
iris = iris.replace(np.nan, 1.0)
iris.head(32)
# Out:
#     sepal_length  sapal_length  petal_length  patal_length        class
# 0            5.1           3.5           1.4           0.2  Iris-setosa
# 1            4.9           3.0           1.4           0.2  Iris-setosa
# 2            4.7           3.2           1.3           0.2  Iris-setosa
# 3            4.6           3.1           1.5           0.2  Iris-setosa
# 4            5.0           3.6           1.4           0.2  Iris-setosa
# 5            5.4           3.9           1.7           0.4  Iris-setosa
# 6            4.6           3.4           1.4           0.3  Iris-setosa
# 7            5.0           3.4           1.5           0.2  Iris-setosa
# 8            4.4           2.9           1.4           0.2  Iris-setosa
# 9            4.9           3.1           1.5           0.1  Iris-setosa
# 10           5.4           3.7           1.0           0.2  Iris-setosa
# 11           4.8           3.4           1.0           0.2  Iris-setosa
# ...

# %% [markdown]
# ### Step 8. Now let's delete the column class

# %%
del iris["class"]
iris
# Out:
#      sepal_length  sapal_length  petal_length  patal_length
# 0             5.1           3.5           1.4           0.2
# 1             4.9           3.0           1.4           0.2
# 2             4.7           3.2           1.3           0.2
# 3             4.6           3.1           1.5           0.2
# 4             5.0           3.6           1.4           0.2
# ..            ...           ...           ...           ...
# 145           6.7           3.0           5.2           2.3
# 146           6.3           2.5           5.0           1.9
# 147           6.5           3.0           5.2           2.0
# 148           6.2           3.4           5.4           2.3
# 149           5.9           3.0           5.1           1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ### Step 9.  Set the first 3 rows as NaN

# %%
iris.iloc[0:3] = np.nan
iris.head(4)
# Out:
#    sepal_length  sapal_length  petal_length  patal_length
# 0           NaN           NaN           NaN           NaN
# 1           NaN           NaN           NaN           NaN
# 2           NaN           NaN           NaN           NaN
# 3           4.6           3.1           1.5           0.2

# %% [markdown]
# ### Step 10.  Delete the rows that have NaN

# %%
iris = iris.dropna()
iris
# Out:
#      sepal_length  sapal_length  petal_length  patal_length
# 3             4.6           3.1           1.5           0.2
# 4             5.0           3.6           1.4           0.2
# 5             5.4           3.9           1.7           0.4
# 6             4.6           3.4           1.4           0.3
# 7             5.0           3.4           1.5           0.2
# ..            ...           ...           ...           ...
# 145           6.7           3.0           5.2           2.3
# 146           6.3           2.5           5.0           1.9
# 147           6.5           3.0           5.2           2.0
# 148           6.2           3.4           5.4           2.3
# 149           5.9           3.0           5.1           1.8
#
# [147 rows x 4 columns]

# %% [markdown]
# ### Step 11. Reset the index so it begins with 0 again

# %%
iris = iris.reset_index()
del iris["index"]
iris
# Out:
#      sepal_length  sapal_length  petal_length  patal_length
# 0             4.6           3.1           1.5           0.2
# 1             5.0           3.6           1.4           0.2
# 2             5.4           3.9           1.7           0.4
# 3             4.6           3.4           1.4           0.3
# 4             5.0           3.4           1.5           0.2
# ..            ...           ...           ...           ...
# 142           6.7           3.0           5.2           2.3
# 143           6.3           2.5           5.0           1.9
# 144           6.5           3.0           5.2           2.0
# 145           6.2           3.4           5.4           2.3
# 146           5.9           3.0           5.1           1.8
#
# [147 rows x 4 columns]

# %% [markdown]
# ### BONUS: Create your own question and answer it.

# %%
# Calc the avg patal length
iris["patal_length"].mean()
# Out:
# np.float64(1.2190476190476192)
