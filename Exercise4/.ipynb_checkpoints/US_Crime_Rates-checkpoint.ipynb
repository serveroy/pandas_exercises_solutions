# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
crime = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv", sep = ",")

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime["Year"] = pd.to_datetime(crime["Year"].astype('str'))

# Wrong: crime.loc[:, "Year"] = pd.to_datetime(list(crime.iloc[:]["Year"])), because a conversion from int64 to string is needed before.

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime = crime.set_index("Year")

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime = crime.drop(columns=["Total"])

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
columns_list = list(crime.columns)[1:]
decades_list = list(set(list((crime.index.year//10) * 10)))
grouping_by_decades = crime.groupby(crime.index.year//10).agg(
    
    Population = ("Population", "last"), 

    Violent = (columns_list[0], "sum"),
    Property = (columns_list[1], "sum"),
    Murder = (columns_list[2], "sum"),
    Forcible_Rape = (columns_list[3], "sum"),
    Robery = (columns_list[4], "sum"),
    Aggravated_assault = (columns_list[5], "sum"),
    Burglary = (columns_list[6], "sum"),
    Larceny_Theft = (columns_list[7], "sum"),
    Vehicle_Theft = (columns_list[8], "sum")
)

grouping_by_decades.index *= 10
grouping_by_decades.index.name = 'Decade'
grouping_by_decades
    

# Change the population, and the content of the index column
# Out:
#         Population   Violent   Property  Murder  Forcible_Rape   Robery  \
# Decade
# 1960     201385000   4134930   45160900  106180         236720  1633510
# 1970     220099000   9607930   91383800  192230         554570  4159020
# 1980     248239000  14074328  117048900  206439         865639  5383109
# 1990     272690813  17527048  119053499  211664         998827  5748930
# 2000     307006550  13968056  100944369  163068         922499  4230366
# 2010     318857056   6072017   44095950   72867         421059  1749809
#
#         Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Decade
# 1960               2158520  13321100       26547700        5292100
# 1970               4702120  28486000       53157800        9739900
# 1980               7619130  33073494       72040253       11935411
# 1990              10568963  26750015       77679366       14624418
# 2000               8652124  21565176       67970291       11412834
# ...

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
# An algorithm that returns the decade for which total_bad (violent + propery + ...) / population is the largest.
# Population is the population in the last year in this decade (maybe do average? - still 2000).

# Result: 2000

avg_list = []
for i in range(len(decades_list)):
    total_bad = sum(grouping_by_decades.iloc[i][:])
    curr_avg = total_bad/grouping_by_decades.iloc[i, 0]
    avg_list.append(curr_avg)

most_dangerous_index = avg_list.index(max(avg_list))
most_dangerous_decade = decades_list[most_dangerous_index]
print(most_dangerous_decade)
# Out:
# 2000
