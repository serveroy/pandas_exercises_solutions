# %% [markdown]
# # Ex1 - Getting and Knowing your Data (chipotle - part b)

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo = pd.read_csv("https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv", sep = '\t')

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# 5  [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...    $10.98
# 6                                                NaN     $1.69
# 7  [Tomatillo Red Chili Salsa, [Fajita Vegetables...    $11.75
# 8  [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...     $9.25
# 9  [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...     $9.25

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
rows_count = chipo.shape[0]
print(rows_count)
# Out:
# 4622

# %%
# Solution 2
print(len(chipo.iloc[:, 0]))
# Out:
# 4622

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
chipo_columns = chipo.columns
print(len(chipo.columns))
# Out:
# 5

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
print(list(chipo.columns))
# Out:
# ['order_id', 'quantity', 'item_name', 'choice_description', 'item_price']

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
print(chipo.iloc[:, 0])
# Out:
# 0          1
# 1          1
# 2          1
# 3          1
# 4          2
#         ...
# 4617    1833
# 4618    1833
# 4619    1834
# 4620    1834
# 4621    1834
# Name: order_id, Length: 4622, dtype: int64

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
# Creating a dictionary order_dict.
# key = item name (unique), value = number of orders for this item

orders_dict = {}

item_names = chipo.iloc[:]['item_name']
unique_items = list(set(item_names))

for item in unique_items:
    orders_count = 0
    for index in range(chipo.shape[0]):
        if (item_names[index] == item):
            orders_count += chipo.iloc[index]['quantity']
    orders_dict[item] = orders_count

orders_list = list(orders_dict.values())
max_orders_index = orders_list.index(max(orders_list))

most_ordered_item = unique_items[max_orders_index]
print(most_ordered_item)

# # Incorrect solution:
# quantity_list = list(chipo.iloc[:]['quantity'])  #
# max_index_quantity = quantity_list.index(max(quantity_list))
# most_ordered_item = chipo.iloc[max_index_quantity]['item_name']
# print(most_ordered_item)
# Out:
# Chicken Bowl

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
most_orders = orders_dict[most_ordered_item]
print(most_orders)
# Out:
# 761

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
# choice_column = list(set(chipo.iloc[:]['choice_description']))
# print(choice_column)

# Did not understand the assignment here

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
total_orders = sum(chipo.iloc[:]['quantity'])
print(total_orders)
# Out:
# 4972

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
items_price = chipo.iloc[:]['item_price']
print(type(items_price[0]))
# Out:
# <class 'str'>

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
float_price = lambda i: float(chipo.iloc[i]['item_price'][1:])
for i in range(chipo.shape[0]):
    chipo.loc[i, 'item_price'] = float_price(i)

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
items_price = chipo.iloc[:]['item_price']
print(items_price[0])
# Out:
# 2.39

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
new_prices = chipo.iloc[:]['item_price']
quantity = chipo.iloc[:]['quantity']
total_revenue = sum(new_prices * quantity)
print(total_revenue)
# Out:
# 39237.020000000055

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
orders_list = list(chipo.iloc[:]['order_id'])
orders_count = orders_list[-1]
print(orders_count)
# Out:
# 1834

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1
print(total_revenue/orders_count)
# Out:
# 21.3942311886587

# %%
# Solution 2
orders_count_second_way = len(list(set(list(chipo.iloc[:]['order_id']))))
print(total_revenue/orders_count_second_way)
# Out:
# 21.3942311886587

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
print(len(unique_items))
# Out:
# 50
